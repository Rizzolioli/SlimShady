# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('../main/log/random_study__20250812.csv', header = None, names = ['Seed', 'Mutation', 
                                                                           'T1 nodes', 'T1 nodes as', 'T1 k_complexity', 'T1 sb_complexity',
                                                                           'T1 sharpness', 
                                                                           'T2 nodes', 'T2 nodes as', 'T2 k_complexity', 'T2 sb_complexity', 
                                                                           'T2 sharpness',
                                                                           'Mut nodes', 'Mut nodes as', 'Mut k_complexity', 'Mut sb_complexity',
                                                                           'Mut sharpness'])

# %%
data.head(12)
# Out:
#     Seed Mutation  T1 nodes  T1 nodes as  T1 k_complexity  T1 sb_complexity  \
# 0      0       S1         3            3               24     224878.946156
# 1      0      ABS         3            3               24     224878.946156
# 2      0       S2         3            3               24     224878.946156
# 3      1       S1         5            6               44      49690.173576
# 4      1      ABS         5            6               44      49690.173576
# 5      1       S2         5            6               44      49690.173576
# 6      2       S1         7           11               44     112445.601148
# 7      2      ABS         7           11               44     112445.601148
# 8      2       S2         7           11               44     112445.601148
# 9      3       S1         3            3               28     268813.299342
# 10     3      ABS         3            3               28     268813.299342
# 11     3       S2         3            3               28     268813.299342
#
#     T1 sharpness  T2 nodes  T2 nodes as  T2 k_complexity  T2 sb_complexity  \
# 0       0.999371       NaN          NaN              NaN               NaN
# 1       0.999371       NaN          NaN              NaN               NaN
# 2       0.999371       3.0          3.0             26.0      27488.854319
# 3       0.989652       NaN          NaN              NaN               NaN
# 4       0.989652       NaN          NaN              NaN               NaN
# 5       0.989652       3.0          3.0             27.0      42636.166828
# 6       0.993686       NaN          NaN              NaN               NaN
# 7       0.993686       NaN          NaN              NaN               NaN
# 8       0.993686       3.0          3.0             23.0      51496.201346
# 9       0.992395       NaN          NaN              NaN               NaN
# 10      0.992395       NaN          NaN              NaN               NaN
# 11      0.992395       3.0          3.0             24.0      69170.862590
#
#     T2 sharpness  Mut nodes  Mut nodes as  Mut k_complexity  \
# 0            NaN         15            38                98
# 1            NaN         12            15                86
# 2       0.994430         21            21               104
# 3            NaN         17            14               107
# 4            NaN         14            21                96
# 5       0.948351         23            23               109
# 6            NaN         19            62               109
# 7            NaN         16            14                97
# 8       0.999608         25            26               113
# 9            NaN         15            30                97
# 10           NaN         12            15                88
# 11      0.999546         21            21               105
#
#     Mut sb_complexity  Mut sharpness
# 0         9206.240520       0.999585
# 1         5239.638198       0.994488
# 2         8367.887862       0.993668
# 3          846.500837       0.938433
# 4           22.978743       0.964210
# 5           19.935102       0.992866
# 6        10561.782116       0.999789
# 7         4396.606188       0.832644
# 8        19625.817088       0.998075
# 9        16480.755700       0.997220
# 10        9967.590878       0.980297
# 11        7504.941463       0.989605

# %%
data['T1 nodes as'] = data.apply(lambda x: x['T1 nodes as'] if x['T1 nodes'] >= x['T1 nodes as'] else x['T1 nodes'], axis = 1)
data['T2 nodes as'] = data.apply(lambda x: x['T2 nodes as'] if x['T2 nodes'] >= x['T2 nodes as'] else x['T2 nodes'], axis = 1)
data['Mut nodes as'] = data.apply(lambda x: x['Mut nodes as'] if x['Mut nodes'] >= x['Mut nodes as'] else x['Mut nodes'], axis = 1)

# %%
data.head(12)
# Out:
#     Seed Mutation  T1 nodes  T1 nodes as  T1 k_complexity  T1 sb_complexity  \
# 0      0       S1         3            3               24     224878.946156
# 1      0      ABS         3            3               24     224878.946156
# 2      0       S2         3            3               24     224878.946156
# 3      1       S1         5            5               44      49690.173576
# 4      1      ABS         5            5               44      49690.173576
# 5      1       S2         5            5               44      49690.173576
# 6      2       S1         7            7               44     112445.601148
# 7      2      ABS         7            7               44     112445.601148
# 8      2       S2         7            7               44     112445.601148
# 9      3       S1         3            3               28     268813.299342
# 10     3      ABS         3            3               28     268813.299342
# 11     3       S2         3            3               28     268813.299342
#
#     T1 sharpness  T2 nodes  T2 nodes as  T2 k_complexity  T2 sb_complexity  \
# 0       0.999371       NaN          NaN              NaN               NaN
# 1       0.999371       NaN          NaN              NaN               NaN
# 2       0.999371       3.0          3.0             26.0      27488.854319
# 3       0.989652       NaN          NaN              NaN               NaN
# 4       0.989652       NaN          NaN              NaN               NaN
# 5       0.989652       3.0          3.0             27.0      42636.166828
# 6       0.993686       NaN          NaN              NaN               NaN
# 7       0.993686       NaN          NaN              NaN               NaN
# 8       0.993686       3.0          3.0             23.0      51496.201346
# 9       0.992395       NaN          NaN              NaN               NaN
# 10      0.992395       NaN          NaN              NaN               NaN
# 11      0.992395       3.0          3.0             24.0      69170.862590
#
#     T2 sharpness  Mut nodes  Mut nodes as  Mut k_complexity  \
# 0            NaN         15            15                98
# 1            NaN         12            12                86
# 2       0.994430         21            21               104
# 3            NaN         17            14               107
# 4            NaN         14            14                96
# 5       0.948351         23            23               109
# 6            NaN         19            19               109
# 7            NaN         16            14                97
# 8       0.999608         25            25               113
# 9            NaN         15            15                97
# 10           NaN         12            12                88
# 11      0.999546         21            21               105
#
#     Mut sb_complexity  Mut sharpness
# 0         9206.240520       0.999585
# 1         5239.638198       0.994488
# 2         8367.887862       0.993668
# 3          846.500837       0.938433
# 4           22.978743       0.964210
# 5           19.935102       0.992866
# 6        10561.782116       0.999789
# 7         4396.606188       0.832644
# 8        19625.817088       0.998075
# 9        16480.755700       0.997220
# 10        9967.590878       0.980297
# 11        7504.941463       0.989605

# %%
data[['Mutation', 'Mut nodes', 'Mut nodes as', 'Mut k_complexity', 'Mut sb_complexity', 'Mut sharpness']].groupby('Mutation').median().T
# Out:
# Mutation                   ABS           S1           S2
# Mut nodes            12.000000    15.000000    23.000000
# Mut nodes as         12.000000    15.000000    22.000000
# Mut k_complexity     88.000000    99.000000   106.000000
# Mut sb_complexity  3678.548985  6553.464077  4870.974802
# Mut sharpness         0.959478     0.994650     0.992542

# %%
data[['Mut nodes', 'Mut nodes as', 'Mut k_complexity', 'Mut sb_complexity', 'Mut sharpness']].corr()
# Out:
#                    Mut nodes  Mut nodes as  Mut k_complexity  \
# Mut nodes           1.000000      0.946193          0.918872
# Mut nodes as        0.946193      1.000000          0.878202
# Mut k_complexity    0.918872      0.878202          1.000000
# Mut sb_complexity  -0.022657     -0.012894         -0.011681
# Mut sharpness      -0.002685     -0.002923         -0.026342
#
#                    Mut sb_complexity  Mut sharpness
# Mut nodes                  -0.022657      -0.002685
# Mut nodes as               -0.012894      -0.002923
# Mut k_complexity           -0.011681      -0.026342
# Mut sb_complexity           1.000000       0.009852
# Mut sharpness               0.009852       1.000000
