# %%
import pandas as pd
from scipy.stats import mannwhitneyu

# %%
data_wdgsm = pd.read_csv('../main/log_crossover' + "/filtered_11nov_wdgsm.csv", names=["algo", "experiment_id", "dataset", "seed", "generation",
                                        "training_fitness", "timing", "pop_node_count",
                                        "test_fitness", "elite_size", "log_level", "algo_type"])

data_wodgsm = pd.read_csv('../main/log_crossover' + "/filtered_11nov_wodgsm.csv", names=["algo", "experiment_id", "dataset", "seed", "generation",
                                        "training_fitness", "timing", "pop_node_count",
                                        "test_fitness", "elite_size", "log_level", "algo_type"])

# %%
data = pd.concat((data_wdgsm, data_wodgsm)).reset_index(drop = True)

# %%
data = data.query("algo in ['XOSw w DGSM', 'SLIM-GSGP', 'XODn w DGSM', 'GSGP', 'XOSw wo DGSM', 'XODn wo DGSM']")

# %%
new_data = data.query("algo == 'GSGP'").copy()

# %%
new_data["algo_type"] = 'SlimGSGP_1_mul_True'

# %%
data = pd.concat((data, new_data)).reset_index(drop = True)

# %%
algo_types = ['SlimGSGP_1_mul_True',  'SlimGSGP_2_sum_True'] #'SlimGSGP_1_mul_False',
datasets =['yatch', 'istanbul', 'airfoil',
       'concrete_strength', 'concrete_slump'] #, 'concrete_slump'

# %%
data.algo.unique()
# Out:
# array(['SLIM-GSGP', 'XOSw w DGSM', 'XODn w DGSM', 'XOSw wo DGSM',
#        'XODn wo DGSM', 'GSGP'], dtype=object)

# %%
for algo_type in algo_types:
    for dataset in datasets:
        # Filter the data for the current algo_type and dataset
        subset = data[(data['algo_type'] == algo_type) & (data['dataset'] == dataset) & (data['generation'] == 1000)]
        
        # Get the list of unique algorithms within the subset
        algorithms = ['SLIM-GSGP', 'XOSw w DGSM', 'XODn w DGSM', 'XOSw wo DGSM',
       'XODn wo DGSM', 'GSGP']
        
        # Create an empty DataFrame for the pairwise comparison matrix
        matrix = pd.DataFrame(index=algorithms, columns=algorithms)
        
        # Loop over each pair of algorithms to calculate Mann-Whitney U test
        for i in range(len(algorithms)):
            for j in range(i + 1, len(algorithms)):
                algo_1 = algorithms[i]
                algo_2 = algorithms[j]
                
                # Extract the test fitness scores for both algorithms
                fitness_algo_1 = subset[subset['algo'] == algo_1]['test_fitness'].values
                fitness_algo_2 = subset[subset['algo'] == algo_2]['test_fitness'].values
                
                # Perform the Mann-Whitney U test
                stat, p_value = mannwhitneyu(fitness_algo_1, fitness_algo_2)

                                # Format p-value in scientific notation
                p_value_sci = f"{p_value:.2e}"  # Change precision as desired
                
                # Store the result in the upper triangle of the matrix
                matrix.loc[algo_1, algo_2] = p_value_sci
                

        # Print LaTeX code for the table
        # print(f"\n\\textbf{{Test Fitness Algorithm Type: {algo_type}, Dataset: {dataset}}}\n")
        print(matrix.to_latex(na_rep="", escape=False, position = '!ht', caption = f"\n\\textbf{{Metric: Test Fitness, Algorithm Type: {algo_type}, Dataset: {dataset}}}\n"))
# Out:
# \begin{table}[!ht]
# \caption{
# \textbf{Metric: Test Fitness, Algorithm Type: SlimGSGP_1_mul_True, Dataset: yatch}
# }
# \begin{tabular}{lllllll}
# \toprule
#  & SLIM-GSGP & XOSw w DGSM & XODn w DGSM & XOSw wo DGSM & XODn wo DGSM & GSGP \\
# \midrule
# SLIM-GSGP &  & 5.52e-01 & 9.02e-09 & 2.53e-04 & 6.65e-09 & 8.15e-10 \\
# XOSw w DGSM &  &  & 3.81e-07 & 8.12e-04 & 2.78e-07 & 1.20e-08 \\
# XODn w DGSM &  &  &  & 8.77e-02 & 8.65e-01 & 6.12e-10 \\
# XOSw wo DGSM &  &  &  &  & 3.64e-02 & 3.08e-08 \\
# XODn wo DGSM &  &  &  &  &  & 6.52e-09 \\
# GSGP &  &  &  &  &  &  \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}[!ht]
# \caption{
# \textbf{Metric: Test Fitness, Algorithm Type: SlimGSGP_1_mul_True, Dataset: istanbul}
# }
# \begin{tabular}{lllllll}
# \toprule
#  & SLIM-GSGP & XOSw w DGSM & XODn w DGSM & XOSw wo DGSM & XODn wo DGSM & GSGP \\
# \midrule
# SLIM-GSGP &  & 8.30e-01 & 6.10e-01 & 2.52e-01 & 1.15e-01 & 1.25e-05 \\
# XOSw w DGSM &  &  & 6.52e-01 & 3.26e-01 & 1.33e-01 & 1.87e-05 \\
# XODn w DGSM &  &  &  & 5.30e-01 & 2.46e-01 & 3.09e-06 \\
# XOSw wo DGSM &  &  &  &  & 6.63e-01 & 3.81e-07 \\
# XODn wo DGSM &  &  &  &  &  & 9.53e-07 \\
# GSGP &  &  &  &  &  &  \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}[!ht]
# \caption{
# \textbf{Metric: Test Fitness, Algorithm Type: SlimGSGP_1_mul_True, Dataset: airfoil}
# }
# \begin{tabular}{lllllll}
# \toprule
#  & SLIM-GSGP & XOSw w DGSM & XODn w DGSM & XOSw wo DGSM & XODn wo DGSM & GSGP \\
# \midrule
# SLIM-GSGP &  & 4.44e-01 & 1.36e-14 & 1.36e-14 & 1.36e-14 & 7.54e-13 \\
# XOSw w DGSM &  &  & 3.02e-11 & 3.02e-11 & 3.02e-11 & 1.55e-09 \\
# XODn w DGSM &  &  &  & 1.10e-08 & 4.55e-01 & 2.96e-05 \\
# XOSw wo DGSM &  &  &  &  & 4.62e-10 & 7.06e-01 \\
# XODn wo DGSM &  &  &  &  &  & 1.87e-05 \\
# GSGP &  &  &  &  &  &  \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}[!ht]
# \caption{
# \textbf{Metric: Test Fitness, Algorithm Type: SlimGSGP_1_mul_True, Dataset: concrete_strength}
# }
# \begin{tabular}{lllllll}
# \toprule
#  & SLIM-GSGP & XOSw w DGSM & XODn w DGSM & XOSw wo DGSM & XODn wo DGSM & GSGP \\
# \midrule
# SLIM-GSGP &  & 4.04e-01 & 2.21e-04 & 3.29e-04 & 1.10e-08 & 1.12e-09 \\
# XOSw w DGSM &  &  & 7.29e-03 & 1.99e-02 & 5.09e-06 & 3.32e-06 \\
# XODn w DGSM &  &  &  & 6.10e-01 & 9.05e-02 & 8.50e-02 \\
# XOSw wo DGSM &  &  &  &  & 6.97e-03 & 1.70e-02 \\
# XODn wo DGSM &  &  &  &  &  & 7.51e-01 \\
# GSGP &  &  &  &  &  &  \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}[!ht]
# \caption{
# \textbf{Metric: Test Fitness, Algorithm Type: SlimGSGP_1_mul_True, Dataset: concrete_slump}
# }
# \begin{tabular}{lllllll}
# \toprule
#  & SLIM-GSGP & XOSw w DGSM & XODn w DGSM & XOSw wo DGSM & XODn wo DGSM & GSGP \\
# \midrule
# SLIM-GSGP &  & 9.49e-01 & 3.56e-02 & 1.29e-01 & 1.45e-02 & 5.62e-03 \\
# XOSw w DGSM &  &  & 7.48e-02 & 1.58e-01 & 5.94e-02 & 1.84e-02 \\
# XODn w DGSM &  &  &  & 6.00e-01 & 7.39e-01 & 5.89e-01 \\
# XOSw wo DGSM &  &  &  &  & 3.33e-01 & 2.71e-01 \\
# XODn wo DGSM &  &  &  &  &  & 9.82e-01 \\
# GSGP &  &  &  &  &  &  \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}[!ht]
# \caption{
# \textbf{Metric: Test Fitness, Algorithm Type: SlimGSGP_2_sum_True, Dataset: yatch}
# }
# \begin{tabular}{lllllll}
# \toprule
#  & SLIM-GSGP & XOSw w DGSM & XODn w DGSM & XOSw wo DGSM & XODn wo DGSM & GSGP \\
# \midrule
# SLIM-GSGP &  & 1.76e-03 & 3.80e-10 & 6.02e-02 & 5.84e-14 & 3.12e-13 \\
# XOSw w DGSM &  &  & 1.58e-04 & 1.76e-01 & 2.23e-09 & 1.36e-07 \\
# XODn w DGSM &  &  &  & 1.29e-06 & 3.59e-05 & 3.03e-02 \\
# XOSw wo DGSM &  &  &  &  & 2.15e-10 & 1.55e-09 \\
# XODn wo DGSM &  &  &  &  &  & 8.56e-04 \\
# GSGP &  &  &  &  &  &  \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}[!ht]
# \caption{
# \textbf{Metric: Test Fitness, Algorithm Type: SlimGSGP_2_sum_True, Dataset: istanbul}
# }
# \begin{tabular}{lllllll}
# \toprule
#  & SLIM-GSGP & XOSw w DGSM & XODn w DGSM & XOSw wo DGSM & XODn wo DGSM & GSGP \\
# \midrule
# SLIM-GSGP &  & 5.11e-01 & 2.58e-01 & 5.69e-01 & 6.97e-03 & 3.27e-02 \\
# XOSw w DGSM &  &  & 1.02e-01 & 1.54e-01 & 1.11e-03 & 3.03e-03 \\
# XODn w DGSM &  &  &  & 6.20e-01 & 1.02e-01 & 2.52e-01 \\
# XOSw wo DGSM &  &  &  &  & 3.64e-02 & 1.33e-01 \\
# XODn wo DGSM &  &  &  &  &  & 4.12e-01 \\
# GSGP &  &  &  &  &  &  \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}[!ht]
# \caption{
# \textbf{Metric: Test Fitness, Algorithm Type: SlimGSGP_2_sum_True, Dataset: airfoil}
# }
# \begin{tabular}{lllllll}
# \toprule
#  & SLIM-GSGP & XOSw w DGSM & XODn w DGSM & XOSw wo DGSM & XODn wo DGSM & GSGP \\
# \midrule
# SLIM-GSGP &  & 1.16e-03 & 1.11e-04 & 1.11e-04 & 1.04e-04 & 9.67e-04 \\
# XOSw w DGSM &  &  & 1.06e-03 & 1.30e-03 & 8.56e-04 & 6.67e-03 \\
# XODn w DGSM &  &  &  & 7.84e-01 & 1.77e-03 & 3.71e-01 \\
# XOSw wo DGSM &  &  &  &  & 2.62e-03 & 1.22e-01 \\
# XODn wo DGSM &  &  &  &  &  & 9.52e-04 \\
# GSGP &  &  &  &  &  &  \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}[!ht]
# \caption{
# \textbf{Metric: Test Fitness, Algorithm Type: SlimGSGP_2_sum_True, Dataset: concrete_strength}
# }
# \begin{tabular}{lllllll}
# \toprule
#  & SLIM-GSGP & XOSw w DGSM & XODn w DGSM & XOSw wo DGSM & XODn wo DGSM & GSGP \\
# \midrule
# SLIM-GSGP &  & 4.38e-02 & 6.67e-04 & 1.67e-06 & 2.58e-05 & 5.89e-07 \\
# XOSw w DGSM &  &  & 1.62e-01 & 3.77e-04 & 9.07e-03 & 7.30e-04 \\
# XODn w DGSM &  &  &  & 1.95e-03 & 6.79e-02 & 1.22e-02 \\
# XOSw wo DGSM &  &  &  &  & 9.33e-02 & 3.48e-01 \\
# XODn wo DGSM &  &  &  &  &  & 5.89e-01 \\
# GSGP &  &  &  &  &  &  \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}[!ht]
# \caption{
# \textbf{Metric: Test Fitness, Algorithm Type: SlimGSGP_2_sum_True, Dataset: concrete_slump}
# }
# \begin{tabular}{lllllll}
# \toprule
#  & SLIM-GSGP & XOSw w DGSM & XODn w DGSM & XOSw wo DGSM & XODn wo DGSM & GSGP \\
# \midrule
# SLIM-GSGP &  & 9.90e-01 & 1.72e-01 & 2.75e-01 & 1.05e-01 & 4.56e-02 \\
# XOSw w DGSM &  &  & 3.11e-01 & 3.26e-01 & 1.41e-01 & 1.22e-01 \\
# XODn w DGSM &  &  &  & 4.68e-02 & 7.17e-01 & 9.07e-03 \\
# XOSw wo DGSM &  &  &  &  & 2.61e-02 & 5.11e-01 \\
# XODn wo DGSM &  &  &  &  &  & 5.57e-03 \\
# GSGP &  &  &  &  &  &  \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
for algo_type in algo_types:
    for dataset in datasets:
        # Filter the data for the current algo_type and dataset
        subset = data[(data['algo_type'] == algo_type) & (data['dataset'] == dataset)& (data['generation'] == 1000)]
        
        # Get the list of unique algorithms within the subset
        algorithms = ['SLIM-GSGP', 'XOSw w DGSM', 'XODn w DGSM', 'XOSw wo DGSM',
       'XODn wo DGSM', 'GSGP']
        
        # Create an empty DataFrame for the pairwise comparison matrix
        matrix = pd.DataFrame(index=algorithms, columns=algorithms)
        
        # Loop over each pair of algorithms to calculate Mann-Whitney U test
        for i in range(len(algorithms)):
            for j in range(i + 1, len(algorithms)):
                algo_1 = algorithms[i]
                algo_2 = algorithms[j]
                
                # Extract the test fitness scores for both algorithms
                fitness_algo_1 = subset[subset['algo'] == algo_1]['elite_size'].values
                fitness_algo_2 = subset[subset['algo'] == algo_2]['elite_size'].values
                
                # Perform the Mann-Whitney U test
                stat, p_value = mannwhitneyu(fitness_algo_1, fitness_algo_2)
                
                # Format p-value in scientific notation
                p_value_sci = f"{p_value:.2e}"  # Change precision as desired
                
                # Store the result in the upper triangle of the matrix
                matrix.loc[algo_1, algo_2] = p_value_sci

        # Print LaTeX code for the table
        # print(f"\n\\textbf{{Elite Size Algorithm Type: {algo_type}, Dataset: {dataset}}}\n")
        print(matrix.to_latex(na_rep="", escape=False, position = '!ht', caption = f"\n\\textbf{{Metric: Elite Size, Algorithm Type: {algo_type}, Dataset: {dataset}}}\n"))
# Out:
# \begin{table}[!ht]
# \caption{
# \textbf{Metric: Elite Size, Algorithm Type: SlimGSGP_1_mul_True, Dataset: yatch}
# }
# \begin{tabular}{lllllll}
# \toprule
#  & SLIM-GSGP & XOSw w DGSM & XODn w DGSM & XOSw wo DGSM & XODn wo DGSM & GSGP \\
# \midrule
# SLIM-GSGP &  & 8.53e-08 & 7.54e-14 & 1.35e-14 & 1.35e-14 & 1.35e-14 \\
# XOSw w DGSM &  &  & 3.01e-11 & 3.01e-11 & 3.01e-11 & 3.01e-11 \\
# XODn w DGSM &  &  &  & 1.75e-05 & 1.56e-01 & 3.02e-11 \\
# XOSw wo DGSM &  &  &  &  & 7.04e-10 & 3.02e-11 \\
# XODn wo DGSM &  &  &  &  &  & 3.02e-11 \\
# GSGP &  &  &  &  &  &  \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}[!ht]
# \caption{
# \textbf{Metric: Elite Size, Algorithm Type: SlimGSGP_1_mul_True, Dataset: istanbul}
# }
# \begin{tabular}{lllllll}
# \toprule
#  & SLIM-GSGP & XOSw w DGSM & XODn w DGSM & XOSw wo DGSM & XODn wo DGSM & GSGP \\
# \midrule
# SLIM-GSGP &  & 8.53e-11 & 3.01e-11 & 3.01e-11 & 3.02e-11 & 3.02e-11 \\
# XOSw w DGSM &  &  & 9.73e-10 & 3.00e-11 & 3.01e-11 & 1.43e-08 \\
# XODn w DGSM &  &  &  & 5.94e-02 & 7.42e-05 & 5.19e-02 \\
# XOSw wo DGSM &  &  &  &  & 6.05e-06 & 1.76e-01 \\
# XODn wo DGSM &  &  &  &  &  & 8.77e-01 \\
# GSGP &  &  &  &  &  &  \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}[!ht]
# \caption{
# \textbf{Metric: Elite Size, Algorithm Type: SlimGSGP_1_mul_True, Dataset: airfoil}
# }
# \begin{tabular}{lllllll}
# \toprule
#  & SLIM-GSGP & XOSw w DGSM & XODn w DGSM & XOSw wo DGSM & XODn wo DGSM & GSGP \\
# \midrule
# SLIM-GSGP &  & 4.69e-04 & 1.36e-14 & 1.36e-14 & 1.36e-14 & 1.36e-14 \\
# XOSw w DGSM &  &  & 3.01e-11 & 3.01e-11 & 3.01e-11 & 3.01e-11 \\
# XODn w DGSM &  &  &  & 1.17e-03 & 1.91e-01 & 3.02e-11 \\
# XOSw wo DGSM &  &  &  &  & 7.11e-09 & 3.02e-11 \\
# XODn wo DGSM &  &  &  &  &  & 3.02e-11 \\
# GSGP &  &  &  &  &  &  \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}[!ht]
# \caption{
# \textbf{Metric: Elite Size, Algorithm Type: SlimGSGP_1_mul_True, Dataset: concrete_strength}
# }
# \begin{tabular}{lllllll}
# \toprule
#  & SLIM-GSGP & XOSw w DGSM & XODn w DGSM & XOSw wo DGSM & XODn wo DGSM & GSGP \\
# \midrule
# SLIM-GSGP &  & 8.41e-01 & 1.36e-14 & 1.36e-14 & 1.36e-14 & 1.36e-14 \\
# XOSw w DGSM &  &  & 3.00e-11 & 3.01e-11 & 3.01e-11 & 3.01e-11 \\
# XODn w DGSM &  &  &  & 1.55e-06 & 2.98e-06 & 3.02e-11 \\
# XOSw wo DGSM &  &  &  &  & 7.12e-01 & 3.02e-11 \\
# XODn wo DGSM &  &  &  &  &  & 3.02e-11 \\
# GSGP &  &  &  &  &  &  \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}[!ht]
# \caption{
# \textbf{Metric: Elite Size, Algorithm Type: SlimGSGP_1_mul_True, Dataset: concrete_slump}
# }
# \begin{tabular}{lllllll}
# \toprule
#  & SLIM-GSGP & XOSw w DGSM & XODn w DGSM & XOSw wo DGSM & XODn wo DGSM & GSGP \\
# \midrule
# SLIM-GSGP &  & 8.07e-01 & 2.28e-14 & 1.33e-14 & 1.33e-14 & 1.33e-14 \\
# XOSw w DGSM &  &  & 3.33e-11 & 3.00e-11 & 3.01e-11 & 3.01e-11 \\
# XODn w DGSM &  &  &  & 8.31e-03 & 2.84e-04 & 3.02e-11 \\
# XOSw wo DGSM &  &  &  &  & 1.25e-02 & 3.01e-11 \\
# XODn wo DGSM &  &  &  &  &  & 3.02e-11 \\
# GSGP &  &  &  &  &  &  \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}[!ht]
# \caption{
# \textbf{Metric: Elite Size, Algorithm Type: SlimGSGP_2_sum_True, Dataset: yatch}
# }
# \begin{tabular}{lllllll}
# \toprule
#  & SLIM-GSGP & XOSw w DGSM & XODn w DGSM & XOSw wo DGSM & XODn wo DGSM & GSGP \\
# \midrule
# SLIM-GSGP &  & 2.42e-13 & 1.36e-14 & 1.36e-14 & 1.36e-14 & 1.36e-14 \\
# XOSw w DGSM &  &  & 3.02e-11 & 3.02e-11 & 3.02e-11 & 3.02e-11 \\
# XODn w DGSM &  &  &  & 3.02e-11 & 1.84e-02 & 3.02e-11 \\
# XOSw wo DGSM &  &  &  &  & 3.02e-11 & 3.02e-11 \\
# XODn wo DGSM &  &  &  &  &  & 3.02e-11 \\
# GSGP &  &  &  &  &  &  \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}[!ht]
# \caption{
# \textbf{Metric: Elite Size, Algorithm Type: SlimGSGP_2_sum_True, Dataset: istanbul}
# }
# \begin{tabular}{lllllll}
# \toprule
#  & SLIM-GSGP & XOSw w DGSM & XODn w DGSM & XOSw wo DGSM & XODn wo DGSM & GSGP \\
# \midrule
# SLIM-GSGP &  & 1.54e-04 & 3.69e-11 & 3.02e-11 & 3.02e-11 & 3.02e-11 \\
# XOSw w DGSM &  &  & 3.02e-11 & 3.02e-11 & 3.02e-11 & 3.02e-11 \\
# XODn w DGSM &  &  &  & 9.67e-09 & 8.24e-02 & 5.79e-01 \\
# XOSw wo DGSM &  &  &  &  & 1.77e-08 & 5.27e-06 \\
# XODn wo DGSM &  &  &  &  &  & 9.23e-01 \\
# GSGP &  &  &  &  &  &  \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}[!ht]
# \caption{
# \textbf{Metric: Elite Size, Algorithm Type: SlimGSGP_2_sum_True, Dataset: airfoil}
# }
# \begin{tabular}{lllllll}
# \toprule
#  & SLIM-GSGP & XOSw w DGSM & XODn w DGSM & XOSw wo DGSM & XODn wo DGSM & GSGP \\
# \midrule
# SLIM-GSGP &  & 1.36e-14 & 1.36e-14 & 1.36e-14 & 1.36e-14 & 1.36e-14 \\
# XOSw w DGSM &  &  & 3.02e-11 & 3.02e-11 & 3.02e-11 & 3.02e-11 \\
# XODn w DGSM &  &  &  & 2.53e-04 & 8.48e-09 & 3.02e-11 \\
# XOSw wo DGSM &  &  &  &  & 3.02e-11 & 3.02e-11 \\
# XODn wo DGSM &  &  &  &  &  & 3.02e-11 \\
# GSGP &  &  &  &  &  &  \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}[!ht]
# \caption{
# \textbf{Metric: Elite Size, Algorithm Type: SlimGSGP_2_sum_True, Dataset: concrete_strength}
# }
# \begin{tabular}{lllllll}
# \toprule
#  & SLIM-GSGP & XOSw w DGSM & XODn w DGSM & XOSw wo DGSM & XODn wo DGSM & GSGP \\
# \midrule
# SLIM-GSGP &  & 1.36e-14 & 1.27e-13 & 1.36e-14 & 1.36e-14 & 1.36e-14 \\
# XOSw w DGSM &  &  & 3.02e-11 & 3.02e-11 & 3.01e-11 & 3.02e-11 \\
# XODn w DGSM &  &  &  & 2.00e-05 & 2.39e-04 & 3.02e-11 \\
# XOSw wo DGSM &  &  &  &  & 7.39e-01 & 3.02e-11 \\
# XODn wo DGSM &  &  &  &  &  & 3.02e-11 \\
# GSGP &  &  &  &  &  &  \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}[!ht]
# \caption{
# \textbf{Metric: Elite Size, Algorithm Type: SlimGSGP_2_sum_True, Dataset: concrete_slump}
# }
# \begin{tabular}{lllllll}
# \toprule
#  & SLIM-GSGP & XOSw w DGSM & XODn w DGSM & XOSw wo DGSM & XODn wo DGSM & GSGP \\
# \midrule
# SLIM-GSGP &  & 1.36e-14 & 1.55e-14 & 1.36e-14 & 1.36e-14 & 1.36e-14 \\
# XOSw w DGSM &  &  & 3.02e-11 & 3.01e-11 & 3.02e-11 & 3.02e-11 \\
# XODn w DGSM &  &  &  & 1.47e-07 & 9.83e-08 & 3.02e-11 \\
# XOSw wo DGSM &  &  &  &  & 1.50e-02 & 3.01e-11 \\
# XODn wo DGSM &  &  &  &  &  & 3.02e-11 \\
# GSGP &  &  &  &  &  &  \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
for dataset in datasets:
    print(dataset)
    gsgp = data.query("dataset == @dataset and algo == 'GSGP' and generation == 1000")
    print(gsgp['elite_size'].median())
# Out:
# yatch
# 3.4146366467495643e+68
# istanbul
# 2427.5
# airfoil
# 2.7368042155397647e+60
# concrete_strength
# 2.1323947178180478e+70
# concrete_slump
# 8.048215556212395e+86
